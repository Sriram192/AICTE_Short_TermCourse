# %%
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sn 
import math
import pandas as pd
from matplotlib import rc 
rc('font', **{'serif':['Helvetica']})
rc('text', usetex=True)
import scipy
import math
import os
from matplotlib import style

# %% [markdown]
# # Reading Data

# %%
den = [0.1,0.5,0.8,1.0]
fig = plt.figure()
ax = fig.add_axes([0.15,0.15,0.80,0.80])
plt.style.use('dark_background')
for i in den:
    print(i)
    rdf = np.genfromtxt('rdf_%.1f.dat'%(i),skip_header = 4)
    ax.plot(rdf[:,1],rdf[:,2],'-o',markersize = 5,linewidth = 2,label = "%0.1f"%i)
plt.xlabel("$r$",fontsize = 20)
plt.ylabel("$g(r)$",fontsize = 20)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.grid()
plt.legend(fontsize = 16)
plt.savefig('den_g_r.jpg',dpi = 600)
# Out:
# 0.1
# 0.5
# 0.8
# 1.0

# %%
eq_data=np.genfromtxt('equilibration.dat',skip_header=1)
pro_data = np.genfromtxt('production.dat',skip_header = 1)

# %% [markdown]
# # Plots

# %%
fig = plt.figure()
ax = fig.add_axes([0.15,0.15,0.80,0.80])
plt.style.use('dark_background')
ax.plot(eq_data[:,0],eq_data[:,3],color = 'orange',linewidth = 2)
plt.xlabel("$steps$",fontsize = 20)
plt.ylabel("$U$",fontsize = 20)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.grid()
plt.savefig('eq_pot.jpg',dpi = 600)

# %%
fig = plt.figure()
ax = fig.add_axes([0.15,0.15,0.80,0.80])
ax.plot(pro_data[:,0],pro_data[:,3],alpha = 0.5,color = 'crimson')
plt.xlabel("$steps$",fontsize = 20)
plt.ylabel("$U$",fontsize = 20)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.grid()
plt.savefig('pro_pot.jpg',dpi = 600)

# %%
fig = plt.figure()
ax = fig.add_axes([0.15,0.15,0.80,0.80])
ax.plot(eq_data[:,0],eq_data[:,1],alpha = 0.5,color = 'blue')
plt.xlabel("$steps$",fontsize = 20)
plt.ylabel("$T$",fontsize = 20)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.grid()
plt.savefig('temp.jpg',dpi = 600)

# %%
fig = plt.figure()
ax = fig.add_axes([0.15,0.15,0.80,0.80])
ax.plot(pot[:,1],pot[:,2],color = 'green',linewidth = 2)
plt.axhline(y=0,color = 'black',ls = '--')
plt.xlabel("$r$",fontsize = 20)
plt.ylabel("$U(r)$",fontsize = 20)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.grid()
plt.savefig('potential.jpg',dpi = 600)
